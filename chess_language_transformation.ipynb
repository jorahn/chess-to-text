# %% [markdown]
# <a href="https://colab.research.google.com/github/jorahn/chess-to-text/blob/main/chess_language_transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chess datasets
# Out:
# Requirement already satisfied: chess in /usr/local/lib/python3.10/dist-packages (1.10.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
import random
import chess
from datasets import load_dataset

# %%
dataset = load_dataset("laion/strategic_game_chess",
    data_files="chess_game_0001.parquet") # load just one 528mb file with ~2m games initially

dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Moves', 'Termination', 'Result'],
#         num_rows: 1999939
#     })
# })

# %%
example = dataset["train"][0]
example
# Out:
# {'Moves': ['d2d4',
#   'f7f5',
#   'g2g3',
#   'g7g6',
#   'f1g2',
#   'f8g7',
#   'g1f3',
#   'd7d6',
#   'c2c3',
#   'e7e6',
#   'a2a4',
#   'g8f6',
#   'd1c2',
#   'd8e7',
#   'b1d2',
#   'e6e5',
#   'd4e5',
#   'd6e5',
#   'e2e4',
#   'b8c6',
#   'e1g1',
#   'f5e4',
#   'd2e4',
#   'c8f5',
#   'f3d2',
#   'e8c8',
#   'b2b4',
#   'g7h6',
#   'f1e1',
#   'h6d2',
#   'c1d2',
#   'f6e4',
#   'g2e4',
#   'e7e6',
#   'd2g5',
#   'd8d6',
#   'a1d1',
#   'd6d1',
#   'e1d1',
#   'h7h6',
#   'g5e3',
#   'a7a5',
#   'c2b1',
#   'h6h5',
#   'b4b5',
#   'c6e7',
#   'e3g5',
#   'h8e8',
#   'h2h4',
#   'e6c4',
#   'd1e1',
#   'f5e4',
#   'e1e4',
#   'c4e6',
#   'g5f4',
#   'e6f5',
#   'f4e5',
#   'e7d5',
#   'b1e1',
#   'd5b6',
#   'f2f4',
#   'b6d7',
#   'e1e2',
#   'b7b6',
#   'e4e3',
#   'e8e7',
#   'e3e4',
#   'd7c5',
#   'e4d4',
#   'e7d7',
#   'g1g2',
#   'c8d8',
#   'g2h2',
#   'd8c8',
#   'e2g2',
#   'c8b8',
#   'g2a2',
#   'b8a7',
#   'a2g2',
#   'a7b8',
#   'g2e2',
#   'b8c8',
#   'e2f3',
#   'c8b8',
#   'f3d1',
#   'b8c8',
#   'd1e2',
#   'c8b8',
#   'e2d1',
#   'b8b7',
#   'd4d7',
#   'c5d7',
#   'e5d4',
#   'd7c5',
#   'h2g2',
#   'f5d5',
#   'g2g1',
#   'd5f5',
#   'd4c5',
#   'f5c5',
#   'd1d4',
#   'c5f5',
#   'd4d2',
#   'f5b1',
#   'g1f2',
#   'b1b3',
#   'd2d4',
#   'b3c2',
#   'f2e3',
#   'b7c8',
#   'd4h8',
#   'c8b7',
#   'h8d4',
#   'b7b8',
#   'd4d8',
#   'b8b7',
#   'd8d5',
#   'b7b8',
#   'd5g8',
#   'b8b7',
#   'g8c4',
#   'b7b8',
#   'c4g8',
#   'b8b7',
#   'g8d5',
#   'b7b8',
#   'd5d8',
#   'b8b7',
#   'd8d4',
#   'b7b8',
#   'd4d8',
#   'b8b7',
#   'd8d3',
#   'c2a4',
#   'd3g6',
#   'a4b5',
#   'g6e4',
#   'b7a7',
#   'f4f5',
#   'a5a4',
#   'f5f6',
#   'a4a3',
#   'f6f7',
#   'b5c5',
#   'e3e2',
#   'c5b5',
#   'e2e3',
#   'b5c5',
#   'e3d3',
#   'c5b5',
#   'd3e3',
#   'b5c5',
#   'e3d3',
#   'c5b5',
#   'e4c4',
#   'b5c4',
#   'd3c4',
#   'a3a2',
#   'f7f8q',
#   'a2a1q',
#   'f8f3',
#   'a1b1',
#   'f3h5',
#   'b1e4',
#   'c4b3',
#   'e4b1',
#   'b3a3',
#   'b1c1',
#   'a3b3',
#   'c1b1',
#   'b3c4',
#   'b1e4',
#   'c4b3',
#   'e4b1',
#   'b3a4',
#   'b1a2',
#   'a4b4',
#   'a2b1',
#   'b4a4',
#   'b1c2',
#   'a4b4',
#   'c2b1',
#   'b4a4',
#   'b1a2',
#   'a4b4',
#   'a2b1',
#   'b4a4',
#   'b1c2',
#   'a4b4',
#   'c2b1',
#   'b4c4',
#   'b1e4',
#   'c4b3',
#   'e4b1',
#   'b3c4',
#   'b1e4',
#   'c4b3',
#   'e4b1'],
#  'Termination': 'FIVEFOLD_REPETITION',
#  'Result': '1/2-1/2'}

# %% [markdown]
# # Transformations
# Source data is in UCI-PGN (https://en.wikipedia.org/wiki/Universal_Chess_Interface) format with ~200 engine moves per game. Includes result and reason for termination (like repetition, insufficient material, checkmate).
# Transformation targets:
# - UCI-PGN Moves -> SAN-PGN Moves
# - UCI-PGN Moves -> LAN-PGN Moves
# - UCI-PGN Moves -> FEN Position

# %%
def uci_to_san(uci_moves, max_half_moves=None):
    # https://en.wikipedia.org/wiki/Algebraic_notation_(chess)#Formatting
    board = chess.Board()
    san_moves = []
    if max_half_moves: uci_moves = uci_moves[:max_half_moves]
    for move_uci in uci_moves:
        move = chess.Move.from_uci(move_uci)
        san_moves.append(board.san(move))
        board.push(move)
    return san_moves

def uci_to_lan(uci_moves, max_half_moves=None):
    # https://en.wikipedia.org/wiki/Algebraic_notation_(chess)#Long_algebraic_notation
    board = chess.Board()
    lan_moves = []
    if max_half_moves: uci_moves = uci_moves[:max_half_moves]
    for move_uci in uci_moves:
        move = chess.Move.from_uci(move_uci)
        lan_moves.append(board.lan(move))
        board.push(move)
    return lan_moves

def uci_to_fen(uci_moves, max_half_moves=None):
    # https://en.wikipedia.org/wiki/Forsyth%E2%80%93Edwards_Notation
    board = chess.Board()
    if max_half_moves: uci_moves = uci_moves[:max_half_moves]
    for move in uci_moves:
        board.push_uci(move)
    return board.fen()

def uci_to_bitboard(uci_moves, max_half_moves=None):
    board = chess.Board()
    if max_half_moves: uci_moves = uci_moves[:max_half_moves]
    for move in uci_moves:
        board.push_uci(move)
    return str(board)

# %%
uci_to_san(example["Moves"], max_half_moves=10)
# Out:
# ['d4', 'f5', 'g3', 'g6', 'Bg2', 'Bg7', 'Nf3', 'd6', 'c3', 'e6']

# %%
uci_to_lan(example["Moves"], max_half_moves=15)
# Out:
# ['d2-d4',
#  'f7-f5',
#  'g2-g3',
#  'g7-g6',
#  'Bf1-g2',
#  'Bf8-g7',
#  'Ng1-f3',
#  'd7-d6',
#  'c2-c3',
#  'e7-e6',
#  'a2-a4',
#  'Ng8-f6',
#  'Qd1-c2',
#  'Qd8-e7',
#  'Nb1-d2']

# %%
uci_to_fen(example["Moves"], max_half_moves=10), uci_to_fen(example["Moves"])
# Out:
# ('rnbqk1nr/ppp3bp/3pp1p1/5p2/3P4/2P2NP1/PP2PPBP/RNBQK2R w KQkq - 0 6',
#  '8/k1p5/1p6/7Q/7P/1KP3P1/8/1q6 w - - 35 100')

# %%
uci_to_bitboard(example["Moves"])
# Out:
# '. . . . . . . .\nk . p . . . . .\n. p . . . . . .\n. . . . . . . Q\n. . . . . . . P\n. K P . . . P .\n. . . . . . . .\n. q . . . . . .'

# %% [markdown]
# # Lanugage Templates
# Insert transformed moves into templates for natural language.

# %%
templates_moves = [
    "{previous_moves} {next_move}",
    "{previous_moves} and then {next_move}.",
    "{previous_moves} followed by {next_move}.",
    "After '{previous_moves}' play {next_move}.",
    "Continue '{previous_moves}' with {next_move}",
    "In a game of chess, after '{previous_moves}' play {next_move}.",
    "In the game of chess, a good move after '{previous_moves}' is {next_move}.",
    "In chess, after the sequence '{previous_moves}' a good move is {next_move}.",
    "In chess after the moves '{previous_moves}', {next_move} is a good move.",
]

templates_fen_move = [
    "In the position '{position}' play {next_move}.",
    "Given the chess position '{position}', a good next move is {next_move}",
    "Starting from the FEN '{position}', a good next move is {next_move}",
]

templates_bitboard_move = [
    "In the position '{position}' play {next_move}.",
    "Given the chess position '{position}', a good next move is {next_move}",
    "Starting from the bitboard position '{position}', a good move is {next_move}",
]

templates_moves_fen = [
    "After '{previous_moves}' the position is '{position}'.",
    "Generate the FEN representation given the PGN of chess game: '{previous_moves}'. The FEN is '{position}'.",
    "Can you produce the FEN code that corresponds to the provided PGN for the chess game: '{previous_moves}'? The FEN notation obtained is '{position}'.",
    "I would appreciate it if you could generate the Forsyth–Edwards Notation (FEN) that corresponds to the given PGN for the chess game: '{previous_moves}'. The FEN code generated is '{position}'.",
    "Please generate the FEN notation for the chess game using the provided PGN: '{previous_moves}'. The obtained FEN representation is '{position}'.",
    "Would you mind generating the FEN code that corresponds to the given PGN for the chess game? The PGN is '{previous_moves}'. The FEN notation generated is '{position}'.",
    "I request you to generate the FEN notation for the given PGN of the chess game: '{previous_moves}'. The FEN code obtained is '{position}'.",
    "Kindly generate the FEN representation that corresponds to the provided PGN of the chess game '{previous_moves}'. The obtained FEN notation is '{position}'.",
    "Could you generate the FEN code for the chess game using the provided PGN: '{previous_moves}'? The FEN notation generated is '{position}'.",
    "It would be great if you could generate the Forsyth–Edwards Notation (FEN) for the chess game using the given PGN '{previous_moves}'. The FEN representation obtained is '{position}'.",
    "May I request you to produce the FEN notation for the provided PGN of the chess game: '{previous_moves}'? The FEN code obtained is '{position}'.",
    "Please generate the FEN code for the chess game based on the provided PGN: '{previous_moves}'. The FEN notation obtained is '{position}'.",
]

templates_moves_bitboard = [
    "After '{previous_moves}' the bitboard position is '{position}'.",
    "Generate the bitboard representation given the PGN of chess game: '{previous_moves}'. The bitboard is '{position}'.",
    "Can you produce the bitboard code that corresponds to the provided PGN for the chess game: '{previous_moves}'? The bitboard obtained is '{position}'.",
    "I would appreciate it if you could generate the bitboard that corresponds to the given PGN for the chess game: '{previous_moves}'. The bitboard code generated is '{position}'.",
    "Please generate the bitboard for the chess game using the provided PGN: '{previous_moves}'. The obtained bitboard representation is '{position}'.",
    "Would you mind generating the bitboard code that corresponds to the given PGN for the chess game? The PGN is '{previous_moves}'. The bitboard generated is '{position}'.",
    "I request you to generate the bitboard for the given PGN of the chess game: '{previous_moves}'. The bitboard obtained is '{position}'.",
    "Kindly generate the bitboard representation that corresponds to the provided PGN of the chess game '{previous_moves}'. The obtained bitboard notation is '{position}'.",
    "Could you generate the bitboard code for the chess game using the provided PGN: '{previous_moves}'? The bitboard generated is '{position}'.",
    "It would be great if you could generate the bitboard for the chess game using the given PGN '{previous_moves}'. The bitboard representation obtained is '{position}'.",
    "May I request you to produce the bitboard for the provided PGN of the chess game: '{previous_moves}'? The bitboard code obtained is '{position}'.",
    "Please generate the bitboard code for the chess game based on the provided PGN: '{previous_moves}'. The bitboard obtained is '{position}'.",
]

templates_moves_result = [
    "After '{moves}' the result is {result}.",
    "A game of chess with the moves '{moves}' ends with the result {result}.",
]

templates_position_move_result = [
    "Given the chess position '{position}', after the move {next_move} the result is {result}.",
    "Starting from the position '{position}' the move {next_move} is played. The game ends with the result {result}.",
]

templates_moves_result_termination = [
    "After '{moves}' the game ends due to {termination} with the result {result}.",
    "A game of chess with the moves '{moves}' ends with the result {result} due to {termination}.",
]

templates_position_move_result_termination = [
    "Given the chess position '{position}', after the move {next_move} the result is {result} due to {termination}.",
    "Starting from the position '{position}' the move {next_move} is played. The game ends due to {termination} with the result {result}.",
]

# %% [markdown]
# # Load Data, apply random Transformations & Templates

# %%
choices = [
    "uci_nextmove",
    "san_nextmove",
    "lan_nextmove",
    "lan_nextmove_piece",
    "fen_nextmove",
    "fen_position",
    "bitboard_nextmove",
    "bitboard_position",
    "uci_result",
    "san_result",
    "lan_result",
    "uci_result_termination",
    "san_result_termination",
    "lan_result_termination",
    "fen_move_result",
    "bitboard_move_result",
    "fen_move_result_termination",
    "bitboard_move_result_termination",
]

# %%
def transform_example(example, fixed_tfm=None):
    tfm = fixed_tfm if fixed_tfm else random.choice(choices)

    if tfm == "uci_nextmove":
        half_moves = random.randint(1, len(example["Moves"])-2)
        previous_moves = " ".join(example["Moves"][:half_moves])
        next_move = example["Moves"][half_moves]

        template = random.choice(templates_moves)
        result = template.format(previous_moves=previous_moves, next_move=next_move)

    elif tfm == "san_nextmove":
        half_moves = random.randint(1, len(example["Moves"])-2)
        moves = uci_to_san(example["Moves"], max_half_moves=half_moves)
        previous_moves = " ".join(moves[:-1])
        next_move = moves[-1]

        template = random.choice(templates_moves)
        result = template.format(previous_moves=previous_moves, next_move=next_move)

    elif tfm == "lan_nextmove":
        half_moves = random.randint(1, len(example["Moves"])-2)
        moves = uci_to_lan(example["Moves"], max_half_moves=half_moves)
        previous_moves = " ".join(moves[:-1])
        next_move = moves[-1]

        template = random.choice(templates_moves)
        result = template.format(previous_moves=previous_moves, next_move=next_move)

    elif tfm == "lan_nextmove_piece":
        half_moves = random.randint(1, len(example["Moves"])-2)
        moves = uci_to_lan(example["Moves"], max_half_moves=half_moves)
        previous_moves = " ".join(moves[:-1])
        next_move = moves[-1]
        if next_move.startswith("N"):
            next_move_piece = f"Night {next_move[1:]}"
        elif next_move.startswith("B"):
            next_move_piece = f"Bishop {next_move[1:]}"
        elif next_move.startswith("R"):
            next_move_piece = f"Rook {next_move[1:]}"
        elif next_move.startswith("Q"):
            next_move_piece = f"Queen {next_move[1:]}"
        elif next_move.startswith("K"):
            next_move_piece = f"King {next_move[1:]}"
        else:
            next_move_piece = f"Pawn {next_move[1:]}"
        next_move_piece = next_move_piece.replace("-", " to ")
        next_move_piece = next_move_piece.replace("x", " captures ")

        template = random.choice(templates_moves)
        result = template.format(previous_moves=previous_moves, next_move=next_move_piece)

    elif tfm == "fen_nextmove":
        half_moves = random.randint(1, len(example["Moves"])-2)
        position = uci_to_fen(example["Moves"], max_half_moves=half_moves)
        next_move = example["Moves"][-1]

        template = random.choice(templates_fen_move)
        result = template.format(position=position, next_move=next_move)

    elif tfm == "fen_position":
        half_moves = random.randint(1, len(example["Moves"])-2)
        position = uci_to_fen(example["Moves"], max_half_moves=half_moves)
        previous_moves = " ".join(example["Moves"][:half_moves])

        template = random.choice(templates_moves_fen)
        result = template.format(position=position, previous_moves=previous_moves)

    elif tfm == "bitboard_nextmove":
        half_moves = random.randint(1, len(example["Moves"])-2)
        position = uci_to_bitboard(example["Moves"], max_half_moves=half_moves)
        next_move = example["Moves"][-1]

        template = random.choice(templates_bitboard_move)
        result = template.format(position=position, next_move=next_move)

    elif tfm == "bitboard_position":
        half_moves = random.randint(1, len(example["Moves"])-2)
        position = uci_to_bitboard(example["Moves"], max_half_moves=half_moves)
        previous_moves = " ".join(example["Moves"][:half_moves])

        template = random.choice(templates_moves_bitboard)
        result = template.format(position=position, previous_moves=previous_moves)

    elif tfm == "uci_result":
        moves = " ".join(example["Moves"])
        result = example["Result"].lower()

        template = random.choice(templates_moves_result)
        result = template.format(moves=moves, result=result)

    elif tfm == "san_result":
        moves = " ".join(uci_to_san(example["Moves"]))
        result = example["Result"].lower()

        template = random.choice(templates_moves_result)
        result = template.format(moves=moves, result=result)

    elif tfm == "lan_result":
        moves = " ".join(uci_to_lan(example["Moves"]))
        result = example["Result"].lower()

        template = random.choice(templates_moves_result)
        result = template.format(moves=moves, result=result)

    elif tfm == "uci_result_termination":
        moves = " ".join(example["Moves"])
        result = example["Result"].lower()
        termination = example["Termination"].lower().replace("_", " ")

        template = random.choice(templates_moves_result_termination)
        result = template.format(moves=moves, result=result, termination=termination)

    elif tfm == "san_result_termination":
        moves = " ".join(uci_to_san(example["Moves"]))
        result = example["Result"].lower()
        termination = example["Termination"].lower().replace("_", " ")

        template = random.choice(templates_moves_result_termination)
        result = template.format(moves=moves, result=result, termination=termination)

    elif tfm == "lan_result_termination":
        moves = " ".join(uci_to_lan(example["Moves"]))
        result = example["Result"].lower()
        termination = example["Termination"].lower().replace("_", " ")

        template = random.choice(templates_moves_result_termination)
        result = template.format(moves=moves, result=result, termination=termination)

    elif tfm == "fen_move_result":
        half_moves = len(example["Moves"]) - 1
        position = uci_to_fen(example["Moves"], max_half_moves=half_moves)
        next_move = example["Moves"][-1]
        result = example["Result"].lower()

        template = random.choice(templates_position_move_result)
        result = template.format(position=position, next_move=next_move, result=result)

    elif tfm == "bitboard_move_result":
        half_moves = len(example["Moves"]) - 1
        position = uci_to_bitboard(example["Moves"], max_half_moves=half_moves)
        next_move = example["Moves"][-1]
        result = example["Result"].lower()

        template = random.choice(templates_position_move_result)
        result = template.format(position=position, next_move=next_move, result=result)

    elif tfm == "fen_move_result_termination":
        half_moves = len(example["Moves"]) - 1
        position = uci_to_fen(example["Moves"], max_half_moves=half_moves)
        next_move = example["Moves"][-1]
        result = example["Result"].lower()
        termination = example["Termination"].lower().replace("_", " ")

        template = random.choice(templates_position_move_result_termination)
        result = template.format(position=position, next_move=next_move, result=result, termination=termination)


    elif tfm == "bitboard_move_result_termination":
        half_moves = len(example["Moves"]) - 1
        position = uci_to_bitboard(example["Moves"], max_half_moves=half_moves)
        next_move = example["Moves"][-1]
        result = example["Result"].lower()
        termination = example["Termination"].lower().replace("_", " ")

        template = random.choice(templates_position_move_result_termination)
        result = template.format(position=position, next_move=next_move, result=result, termination=termination)

    else:
        raise NotImplementedError(f"Transformation {tfm} is not implemented.")

    return result

# %%
transform_example(example, fixed_tfm="bitboard_move_result_termination")
# Out:
# "Starting from the position '. . . . . . . .\nk . p . . . . .\n. p . . . . . .\n. . . . . . . Q\n. . . . q . . P\n. K P . . . P .\n. . . . . . . .\n. . . . . . . .' the move e4b1 is played. The game ends due to fivefold repetition with the result 1/2-1/2."

# %%
for i in range(50):
    print(transform_example(dataset["train"][i]))
    print("---")
# Out:
# In chess after the moves 'd2-d4 f7-f5 g2-g3 g7-g6 Bf1-g2 Bf8-g7 Ng1-f3 d7-d6 c2-c3 e7-e6 a2-a4 Ng8-f6 Qd1-c2 Qd8-e7 Nb1-d2 e6-e5 d4xe5 d6xe5 e2-e4 Nb8-c6 O-O f5xe4', Nd2xe4 is a good move.
# ---
# Starting from the FEN '6k1/1p3q2/8/p1P2b2/3r1B1p/2P2Q1P/P1P3PK/8 w - - 0 37', a good next move is g5g3
# ---
# After 'd2d4 g8f6 c2c4 e7e5 d4e5 f6g4 c1f4 b8c6 g1f3 f8b4 b1d2 d7d6 e5d6 b4d6 f4d6 d8d6 e2e3 c8f5 f1e2 g4e5 e1g1 e8c8 d1a4 d6g6 f3h4 g6e6 h4f5 d8d2 f5g3 h8d8 b2b4 h7h5 e2h5 e6c4 a2a3 g7g6 a1c1 c4d3 h5d1 e5c4 a4b3 b7b5 a3a4 a7a6 b3d3 d8d3 d1g4 f7f5 a4b5 a6b5 g3f5 g6f5 g4f5 c8b7 f5d3 d2d3 g2g4 c6b4 f1d1 c4e5 g4g5 e5f3 g1f1 f3g5 h2h4 g5f7 d1d3 b4d3 c1b1 b7c6 f1e2 d3c5 f2f3 c5d7 h4h5 d7f6 b1h1 c6d6 h5h6 f6h7 e3e4 b5b4 f3f4 b4b3 e2d3 d6e6 h1g1 h7f6 e4e5 f6d5 d3e4 d5c3 e4d3 c3d5 h6h7 d5f4 d3d2 f7h8 g1g7 c7c5 g7c7 e6e5 c7c5 e5f6 c5c8 f6g7 c8h8 b3b2 d2c2 f4d5 c2b2 d5f6 h8g8 g7h7 g8g7 h7h6 g7g6 h6g6' the game ends due to insufficient material with the result 1/2-1/2.
# ---
# In a game of chess, after 'c2c4 g8f6 b1c3 e7e5 g2g3 g7g6 f1g2 f8g7 g1f3 b8c6 d2d4 e5d4 f3d4 e8g8 e1g1 f8e8 h2h3 f6h5 d4c2 d7d6 g3g4 h5f6 f2f4 f6d7 d1d2 a7a5 b2b3 a5a4 a1b1 a4b3 a2b3 d7c5 b3b4 c5a4 c3d5 c8e6 b1b3 a4b6 d2d3 a8a2 d5b6 c7b6 b3b1 b6b5 c4b5 c6e7 c2e3 f7f5 f1d1 d6d5 g4f5 g6f5 g1f1 d5d4 e3c2 e6d5 c2d4 g7d4 g2d5 d8d5 d3d4 d5h1 d4g1 h1g1 f1g1 e7g6 b1b2 a2b2 c1b2 g6f4 g1f1 e8e2 b2c1 e2e4 d1d8 g8f7 d8d7 f7e6 d7b7 e4b4 c1f4 b4f4 f1g2 f4b4 b7h7 b4b5 h7a7 f5f4 a7a6 e6e7 a6a1 e7f6 h3h4 b5b7 h4h5 f4f3 g2g1 f6g7 h5h6 g7h7 g1f2 b7f7 a1a2 f7c7 a2a1 c7b7 a1a2 b7c7 a2a1 c7e7 f2f3 e7f7 f3g4 f7b7 g4f5 b7b5 f5f6 b5b6 f6e5 b6b5 e5e6 h7h6 a1h1 h6g6 h1a1 g6h5 e6f6 h5g4 a1a2 g4g3 a2a8 g3g4 a8a1 g4f4 a1a4 f4e3 a4a8 b5b6 f6g5 b6b5 g5g4 b5b1 a8e8 e3d3 e8e7 d3c4 g4g5 c4c5 g5g4 c5c4 g4g5 b1b8 e7h7 b8b2 g5g4 c4b4 h7b7 b4c3 b7c7 c3b4 c7d7 b2c2 g4f3 b4b5 d7f7 c2c3 f3f2 b5b6 f7e7 c3c2 f2e1 c2a2 e1d1 a2a4 d1c1 a4c4 c1b1 c4f4 e7g7 f4f2 g7h7 f2d2 b1a1 d2d3 a1a2 d3f3 h7h6 b6b5 h6h5 b5b4 h5h4 b4c3 h4h7 c3d4 h7d7 d4e5 d7c7 e5f6 c7c5 f3f5 c5c6 f6g5 c6c7 f5f4 a2a3 f4f3 a3a4 f3f8 c7c5 g5g4 a4b5 f8e8 c5c2 e8e5 b5a6 e5e1 a6b6 e1e6 c2c6 e6e7 c6c1 e7e1 c1e1 g4f4 b6a7 f4g4 e1f1 g4g5 a7b7 g5g4 f1f6 g4g3 b7c6 g3g4 c6c5 g4g5 f6f1 g5g4 f1b1 g4f4 c5d4 f4f3 b1b2 f3g4 d4e4 g4g5 b2f2 g5g6 e4e5' play g6g7.
# ---
# A game of chess with the moves 'd4 Nf6 c4 e6 Nc3 Bb4 Qc2 c5 dxc5 Bxc5 Nf3 d5 Bg5 dxc4 e3 Be7 Bxc4 h6 Bf4 Bd7 O-O O-O a3 Bc6 Nd4 Qb6 Rad1 Be8 b4 a6 e4 Nh5 Be3 Qc7 Ba2 Bf6 f4 Bxd4 Rxd4 Bb5 Rf3 Nc6 Rd1 Rfd8 Rf2 Nf6 h3 Rxd1+ Qxd1 Ne7 Rc2 Rd8 Nd5 Bc6 Nxf6+ gxf6 Qg4+ Kh8 Qe2 Kg7 a4 Qb8 Qg4+ Kh7 Qh5 Kg8 f5 Qe5 Qg4+ Kh7 fxe6 Bxe4 Rc5 Qa1+ Rc1 Qxa2 Qxe4+ f5 Qxb7 Qxe6 Bf2 Ng6 b5 axb5 Re1 Qb3 a5 Rg8 Qd7 Nh4 Bxh4 Kg6 Bf2 b4 Qb5 Qc3 a6 b3 Re3 Qc1+ Kh2 Qc2 Rg3+ Kh7 Qxb3 Qxb3 Rxb3 Ra8 a7 Rxa7 Bxa7 f4 Rb1 f5 Kh1 f3 Rb7+ Kg8 Bf2 f4 h4 h5 Rb2 Kg7 Rb7+ Kg8 Rd7 fxg2+ Kxg2 Kf8 Rd8+ Ke7 Rd1 Kf8 Kh1 Kg7 Rd7+ Kg8 Rd8+ Kh7 Rd5 Kg8 Bc5 Kh8 Bd4+ Kg8 Rg5+ Kh7 Rg7+ Kh6 Rg2 Kh7 Rg7+ Kh6 Rd7 Kg6 Bb2 Kf5 Kg1 Ke4 Kf2 Kf5 Kf1 Kg6 Bh8 Kf5 Rd6 Kg4 Rb6 Kf3 Rb3+ Kg4 Kf2 Kxh4 Bc3 Kg4 Kf1 Kg5 Rb5+ Kg6 Bd2 Kh7 Ra5 Kg8 Bc3 f3 Rxh5 Kf8 Rf5+ Ke7 Kf2 Ke6 Rf6+ Kd5 Kxf3 Kc4 Be1 Kd4 Ke2 Kd5 Ke3 Ke5 Rb6 Kd5 Bb4 Ke5 Bf8 Kf5 Rc6 Ke5 Rd6 Kf5 Kf3 Ke5 Be7 Kf5 Rd1 Ke6 Bd6 Kf7 Kf4 Kf6 Bb8 Kf7 Rd7+ Ke6 Rd4 Kf7 Kf5 Ke7 Be5 Kf8 Kf6 Kg8 Rh4 Kf8 Rh8#' ends with the result 1-0 due to checkmate.
# ---
# Starting from the position '. . . . . . . .
# . . . N . . . .
# k . K . . . . .
# . . . . . . P .
# . . R . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .' the move c4a4 is played. The game ends due to checkmate with the result 1-0.
# ---
# After 'd2-d4 d7-d5 c2-c4 e7-e6 Nb1-c3 Ng8-f6 Bc1-g5 Bf8-b4 e2-e3 c7-c5 c4xd5 Qd8-a5 Bg5xf6 Bb4xc3+ b2xc3 Qa5xc3+ Ke1-e2 g7xf6 Ra1-c1 Qc3-b4 d4xc5 Nb8-a6 Qd1-d4 b7-b6 Ng1-f3 O-O Qd4xb4 Na6xb4 d5xe6 Bc8xe6 Nf3-d4 Nb4xa2 Rc1-a1 Be6-d5 c5-c6 Rf8-c8 Ke2-e1 Na2-b4 Bf1-a6 Nb4xa6 Ra1xa6 Bd5xc6 Nd4xc6 Rc8xc6 Ke1-e2 Rc6-c7 Rh1-d1 Kg8-g7 Rd1-d4 h7-h5 Rd4-a4 Rc7-b7 g2-g4 b6-b5 Ra4-b4 Ra8-c8 g4xh5 Rc8-c5 h5-h6+ Kg7-h8 Ke2-f3 Rc5-e5 Ra6-a5 Re5-f5+ Kf3-g4 Rf5-g5+ Kg4-f3 Kh8-h7 h2-h4 Rg5-e5 Kf3-g3 Kh7xh6 Kg3-f3 Kh6-h5 Kf3-g3 Re5-f5 Ra5-a6 Kh5-g6 Ra6-a5 Rf5-e5 Rb4-g4+ Kg6-h7 Rg4-b4 Re5-f5 Rb4-a4 Rf5-e5 Ra4-b4 Re5-c5 Rb4-b1 Kh7-g8 Rb1-b4 Kg8-f8 Kg3-g4 Rc5-e5 Kg4-g3 Kf8-e7 f2-f4 Re5-c5 Kg3-g4 Ke7-f8 Ra5-a6 Kf8-g8 h4-h5 Kg8-h7 e3-e4 f6-f5+ e4xf5 Kh7-g7 f5-f6+ Kg7-h6 Rb4-e4 Rc5-c8 Re4-b4 Rc8-g8+ Kg4-f5 Rg8-a8 Kf5-g4 Ra8-g8+ Kg4-f3 Rg8-b8 Kf3-g4 Rb7-c7 Ra6-a5 a7-a6 Ra5xa6 Rb8-g8+ Kg4-f3 Rc7-c3+ Kf3-f2 Rg8-d8 Kf2-e2 Rd8-e8+ Ke2-f2 Re8-d8 Kf2-e2 Rc3-h3 Rb4xb5 Rd8-e8+ Ke2-d2 Re8-g8 Rb5-g5 Rg8-d8+ Kd2-e2 Rd8-d4 Ra6-a8 Rd4-e4+ Ke2-d2 Re4-d4+ Kd2-c1 Rd4-c4+ Kc1-b1 Rc4xf4 Rg5-g2 Rh3-h1+ Kb1-b2 Rf4-f2+ Rg2xf2 Rh1xh5 Ra8-h8+ Kh6-g6 Rh8-g8+ Kg6-h7 Rf2-g2 Rh5-b5+ Kb2-a3 Rb5-a5+ Ka3-b4 Ra5-g5 Rg2xg5 Kh7-h6 Rg5-g7 Kh6-h5 Rg8-h8#' the game ends due to checkmate with the result 1-0.
# ---
# A game of chess with the moves 'g1f3 d7d5 e2e3 g8f6 b2b3 c8g4 h2h3 g4f5 c1b2 f5g6 f1e2 e7e6 c2c4 f8d6 e1g1 d8e7 d2d3 h7h6 a2a3 c7c6 b3b4 b8d7 b1d2 e6e5 f3h4 g6h7 e3e4 d5e4 d3e4 f6e4 d2e4 h7e4 e2g4 e8c8 d1e2 e4h7 a1d1 h6h5 g4d7 d8d7 e2h5 e7e6 f1e1 d7d8 b2e5 h7d3 h5h8 d8h8 e5g7 e6e1 d1e1 h8h4 e1d1 h4c4 f2f4 d6e7 d1d3 c4f4 g2g3 f4f5 g1g2 a7a5 h3h4 a5b4 a3b4 f5h5 g7c3 c6c5 b4c5 h5c5 g2h3 b7b5 c3b4 c5c7 b4e7 c7e7 h4h5 e7e1 d3f3 b5b4 h3g4 b4b3 f3b3 c8d7 g4f4 d7e6 b3e3 e1e3 f4e3 e6f5 g3g4 f5e5 e3f3 e5d5 f3f4 d5c4 f4f5 c4d3 h5h6 d3c4 f5f6 c4b3 g4g5 b3b4 h6h7 b4a3 f6f7 a3a2 g5g6 a2b3 g6g7 b3a2 h7h8q a2b3 g7g8q b3c4 g8b8 c4d3 b8b3 d3e4 h8h4 e4f5 b3e6' ends with the result 1-0.
# ---
# g1f3 d7d5 g2g3 c8g4 f1g2 b8d7 e1g1 e7e6 d2d3 g8f6 b2b3 c7c6 b1d2 f8e7 c1b2 a7a5 h2h3 g4h5 g3g4 h5g6 f3h4 e8g8 h4g6 h7g6 c2c4 f6h7 g1h1 e7d6 e2e3 f8e8 d1c2 g6g5 a1c1 a8c8 h1g1 h7f8 d3d4 d8e7 d2f3 f8g6 g1h1 e8d8 f1d1 d8f8 c4d5 e6d5 c2f5 d7f6 f5g5 f8e8 b2c3 e7e6 c3e1 f6e4 g5h5 e4f6 h5f5 e6e7 h3h4 f6e4 g4g5 c8c7 f5h3 d6a3 c1c2 a3b4 h1g1 e7d8 h3g4 e8e6 g2f1 c7e7 e1b4 a5b4 f1d3 d8e8 d1c1 g6f8 f3e5 f7f6 d3e4 d5e4 g5f6 e6f6 c2c5 e8d8 h4h5 d8e8 c5a5 f6h6 g1g2 h6h5 a5a8 h5h2 g2h2 e8a8 c1h1 a8a2 h2g2 a2b3 g4h5 e7e5 h5e5 b3c4 h1h4 c4e6 e5h5 e6g6 h5g6 f8g6 h4e4 b4b3 d4d5 c6c5 d5d6 g6f8 e4e8 b3b2 d6d7 b2b1q d7d8q b1f5 e3e4 f5g6 g2f1 g6f7 e8e7 f7g6 d8d5 g8h7 and then e7b7.
# ---
# Given the chess position '6k1/2p2p2/1p3Qp1/4P3/P4P2/2q4P/P3K3/8 w - - 18 58', after the move f6d8 the result is 1/2-1/2 due to fivefold repetition.
# ---
# A game of chess with the moves 'c2c4 g7g6 b1c3 f8g7 e2e4 d7d6 d2d4 g8f6 f1e2 e8g8 c1g5 b8a6 d1d2 e7e5 d4d5 d8e8 b2b3 c8d7 a1c1 a6c5 g5f6 g7f6 b3b4 c5a4 c3a4 d7a4 g1f3 c7c6 e1g1 f6g7 h2h4 a7a6 h4h5 c6d5 h5h6 g7f6 d2d5 e8d7 b4b5 d7c7 c1b1 f6e7 b1b4 a6b5 c4b5 c7c5 d5c5 d6c5 b4b2 f8d8 e2c4 e7f6 f1b1 g8f8 c4d5 d8d5 e4d5 e5e4 f3d2 a8d8 d2e4 f6b2 b1b2 d8d5 f2f3 f8e7 g1f2 e7e6 e4c3 d5d4 b2e2 e6d7 e2e5 d7d6 e5e8 a4c2 e8b8 d6c7 b8f8 d4d2 f2g3 d2d7 g3f4 c7b6 f4e5 b6a5 a2a3 c5c4 f8c8 c2b3 c8a8 a5b6 a3a4 b6c5 a8c8 c5b4 c3d5 b4a3 a4a5 c4c3 d5c3 a3b4 a5a6 b7b6 e5f6 g6g5 g2g4 b3c4 c3e4 c4b5 c8h8 d7d3 a6a7 d3f3 f6g5 b5c6 a7a8b c6a8 h8a8 b6b5 a8h8 b4a3 h8h7 b5b4 h7h8 f3h3 h8b8 b4b3 e4d2 a3a4 b8b3 f7f6 g5g6 h3h2 b3f3 h2d2 f3f6 d2g2 g4g5 a4b3 h6h7 g2h2 f6b6 b3a2 b6b7 h2h1 g6f5 a2a3 f5g6 a3a2 g6g7 h1g1 h7h8q g1g5 g7h6 g5h5 h6h5 a2a3 h8a8' ends with the result 1-0.
# ---
# After 'e2-e4 c7-c5 f2-f4 e7-e6 d2-d3 a7-a6 Bf1-e2 d7-d5 Ng1-f3 b7-b5 c2-c4 Bf8-e7 c4xd5 e6xd5 O-O Ng8-f6 e4-e5 Nf6-d7 d3-d4 c5-c4 f4-f5 Nd7-b6 Nf3-e1 Nb8-c6 Be2-h5 g7-g6 f5-f6 Be7-f8 Bh5-g4 Bc8xg4 Qd1xg4 Qd8-d7 Qg4-h4 b5-b4 Bc1-e3 h7-h6 Nb1-d2 Qd7-e6 b2-b3 a6-a5 Ne1-c2 a5-a4 h2-h3 Ke8-d8 Qh4-g3 Kd8-c7 b3xc4 d5xc4 Be3-f2 b4-b3 Nc2-e3 Nc6xd4 Kg1-h1 b3-b2 Ra1-d1 Ra8-d8 Nd2-e4 Nd4-b5 Rd1xd8 Kc7xd8 Ne3-c2 Nb6-d5 Bf2-c5 Kd8-c7 Bc5xf8 Rh8xf8 Nc2-a3 Nb5xa3 Qg3xa3 Rf8-b8 Rf1-b1 Qe6xe5 Qa3-c5+ Kc7-d7 Ne4-c3 Qe5-d6 Qc5-a7+ Kd7-c8 Qa7-d4 Kc8-d8 Rb1-d1 Kd8-d7 Qd4-e4 a4-a3 Qe4xc4 Rb8-b4 Qc4-e2 h6-h5 Qe2-e1 Rb4-c4 Nc3xd5 Rc4-c1 Rd1xc1 b2xc1=Q Qe1xc1 Qd6xd5 Qc1xa3 Qd5-c4 Qa3-e7+ Kd7-c6 Qe7-e8+ Kc6-d6 Qe8-b8+ Kd6-d7 Qb8-b7+ Kd7-d6 Qb7-b8+ Kd6-d7 Qb8-b2 h5-h4 Kh1-g1 Qc4-c5+ Kg1-h1 Qc5-c4 Kh1-g1 Qc4-d5 a2-a3 g6-g5 Qb2-b4 Kd7-c6 a3-a4 Qd5-d1+ Kg1-f2 Qd1-a1 Qb4-e4+ Kc6-d6 Qe4-e7+ Kd6-c6 Qe7-e4+ Kc6-d6 Kf2-f3 Qa1-d1+ Qe4-e2 Qd1xa4 Qe2-e7+ Kd6-d5 Qe7xf7+ Kd5-e5 Qf7-e7+ Ke5-f5 f6-f7 Qa4-b3+ Kf3-f2 Qb3-c2+ Qe7-e2 Qc2-c5+ Qe2-e3 Qc5-c2+ Kf2-f3 Qc2-d1+ Kf3-f2 Qd1-c2+ Kf2-f3 Qc2-d1+ Qe3-e2 Qd1-d5+ Kf3-f2 Qd5xf7 Qe2-f3+ Kf5-g6 Qf3xf7+ Kg6xf7 Kf2-f3 Kf7-g7 g2-g3 h4xg3 Kf3xg3 Kg7-h6 Kg3-f3 Kh6-h5 Kf3-e4 Kh5-h4 Ke4-f5 Kh4xh3 Kf5xg5' the game ends due to insufficient material with the result 1/2-1/2.
# ---
# Given the chess position '. . . . . . . .
# . . K . . . . .
# . . . . . . . P
# . . . . . . k .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .', after the move g5h6 the result is 1/2-1/2 due to insufficient material.
# ---
# A game of chess with the moves 'e2-e4 e7-e5 Nb1-c3 Nb8-c6 Bf1-c4 Ng8-f6 a2-a3 Bf8-c5 d2-d3 d7-d6 Nc3-a4 Bc5-b6 Ng1-f3 O-O c2-c3 Nc6-e7 Na4xb6 a7xb6 Bc1-g5 Ne7-g6 Nf3-h4 Ng6-f4 O-O c7-c6 Rf1-e1 b6-b5 Bc4-a2 Rf8-e8 Qd1-f3 Bc8-g4 Bg5xf6 Qd8-d7 Qf3-e3 g7xf6 d3-d4 Kg8-g7 Ba2-b1 Bg4-e6 Bb1-c2 Nf4-g6 Qe3-g3 Re8-g8 Kg1-h1 Kg7-f8 Ra1-d1 Qd7-c7 Nh4-f5 Be6xf5 e4xf5 Ng6-f4 Qg3-h4 Nf4xg2 Qh4-h6+ Kf8-e7 Re1-e4 d6-d5 Re4-e2 e5-e4 Bc2xe4 Ng2-f4 Re2-e3 Ke7-d7 Be4-c2 Qc7-d6 Rd1-g1 Ra8-e8 Qh6xh7 Rg8-f8 Rg1-g7 Kd7-c8 Qh7-h4 Rf8-h8 Qh4-g3 Re8-d8 Re3-f3 Nf4-h3 Qg3xd6 Rd8xd6 Kh1-g2 Nh3-g5 Rf3-f4 Ng5-h3 Rf4-f3 Nh3-g5 Rf3-f4 Ng5-h3 Rf4-g4 Rd6-d7 Rg7-g8+ Rd7-d8 Rg8xd8+ Kc8xd8 f2-f4 Kd8-c8 Bc2-d3 Nh3-f2 Kg2xf2 Rh8xh2+ Kf2-e1 Kc8-d7 Rg4-g7 Kd7-e7 Rg7-g8 Ke7-d6 Rg8-f8 Rh2-h7 Bd3-f1 Kd6-d7 b2-b3 Kd7-d6 a3-a4 b5xa4 b3xa4 Kd6-c7 c3-c4 d5xc4 Bf1xc4 Rh7-h4 Rf8xf7+ Kc7-b8 Rf7xf6 Rh4xf4 Rf6-f8+ Kb8-c7 Bc4-d3 Rf4xd4 Rf8-f7+ Kc7-d6 Bd3-c2 Rd4-b4 Rf7-f6+ Kd6-c5 Rf6-e6 Rb4-c4 Re6-e2 Rc4-f4 a4-a5 Kc5-b5 Re2-f2 Rf4-h4 f5-f6 Rh4-h8 Rf2-f5+ c6-c5 f6-f7 Rh8-f8 Bc2-b3 Kb5xa5 Rf5-g5 Rf8-h8 Rg5-g8 Rh8-h4 Ke1-f2 Ka5-b4 Kf2-g3 Rh4-d4 Bb3-e6 Rd4-d6 Rg8-e8 Kb4-c3 Kg3-f4 Rd6-d4+ Kf4-g5 Rd4-d3 Re8-c8 b7-b6 Rc8-h8 Rd3-d1 Be6-g4 Rd1-d5+ Kg5-h4 Rd5-d6 Kh4-g5 Kc3-b4 Bg4-f5 Rd6-d1 f7-f8=Q Rd1-g1+ Kg5-f6 Kb4-c3 Qf8-d6 Rg1-g3 Qd6xg3+ Kc3-c4 Rh8-h4+ Kc4-b5 Qg3-d3+ c5-c4 Qd3xc4+ Kb5-a5 Qc4-a4#' ends with the result 1-0 due to checkmate.
# ---
# A game of chess with the moves 'd2-d4 Ng8-f6 c2-c4 e7-e6 Ng1-f3 Bf8-b4+ Nb1-d2 O-O a2-a3 Bb4-e7 e2-e3 b7-b6 e3-e4 d7-d5 e4-e5 Nf6-d7 c4xd5 e6xd5 Bf1-d3 c7-c5 O-O Rf8-e8 Nd2-e4 Nb8-c6 Ne4-g3 Nd7-f8 Bd3-b5 Bc8-b7 Ng3-f5 Nf8-e6 h2-h4 a7-a6 Bb5-a4 Be7-f8 Bc1-g5 Ne6xg5 h4xg5 b6-b5 Ba4-c2 Bb7-c8 Rf1-e1 Bc8xf5 Bc2xf5 g7-g6 Bf5-g4 Nc6xd4 Nf3xd4 c5xd4 f2-f4 h7-h5 Bg4-h3 Ra8-a7 Qd1-d3 Ra7-c7 e5-e6 Bf8-c5 g2-g3 Kg8-g7 Re1-e5 f7xe6 Ra1-e1 Rc7-e7 Re5xe6 Re7xe6 Re1xe6 Re8xe6 Bh3xe6 Qd8-d6 Be6-h3 Qd6-e7 Kg1-f1 Bc5-b6 Qd3-e2 Qe7xe2+ Kf1xe2 d4-d3+ Ke2xd3 Bb6-f2 g3-g4 h5-h4 Kd3-e2 Bf2-d4 b2-b3 Bd4-b2 a3-a4 b5xa4 b3xa4 Bb2-c1 Ke2-f3 a6-a5 Bh3-f1 Kg7-f7 Bf1-d3 Bc1-d2 Bd3-b1 Kf7-g7 Bb1-a2 d5-d4 Ba2-c4 h4-h3 Kf3-g3 h3-h2 Kg3xh2 Bd2xf4+ Kh2-g2 Bf4xg5 Kg2-f3 Kg7-h6 Kf3-e4 Bg5-f6 Ke4-f4 Bf6-g5+ Kf4-e5 Bg5-e3 Ke5-e4 Kh6-g5 Ke4-f3 Kg5-f6 Kf3-e4 Be3-g1 Ke4-f4 Bg1-e3+ Kf4-e4 Be3-f2 Ke4-f3 Bf2-e1 Bc4-d3 Be1-c3 Kf3-e4 Kf6-g5 Bd3-e2 Bc3-a1 Ke4-f3 Ba1-c3 Kf3-e4 Kg5-h4 Ke4-f3 Bc3-d2 Be2-f1 Bd2-e3 Bf1-e2 Kh4-g5 Be2-c4 Be3-f4 Bc4-d3 Bf4-c1 Bd3-e2 Bc1-f4 Be2-d3 Bf4-h2 Kf3-g2 Bh2-e5 Kg2-f3 Be5-g7 Bd3-b5 Kg5-f6 Kf3-e4 Bg7-h8 Bb5-c4 Kf6-g5 Bc4-e2 Bh8-f6 Ke4-f3 Kg5-h4 Be2-d3 g6-g5 Bd3-f5 Kh4-h3 Kf3-e4 Kh3-g3 Ke4-d3 Kg3-f4 Bf5-d7 Kf4-e5 Kd3-d2 Ke5-d6 Bd7-f5 Bf6-h8 Kd2-c2 Bh8-f6 Kc2-d3 Bf6-h8 Kd3-c2 Kd6-c6 Kc2-d3 Bh8-f6 Bf5-c8 Bf6-g7 Kd3-c4 Bg7-h8 Bc8-a6 Kc6-d6 Ba6-b5 Kd6-e5 Kc4-d3 Ke5-d6 Bb5-a6 Kd6-d5 Ba6-b7+ Kd5-c5 Bb7-c8 Kc5-d6 Bc8-f5 Kd6-d5 Bf5-d7 Kd5-d6 Bd7-c8 Kd6-c6 Kd3-c4 Kc6-d6 Bc8-a6 Bh8-g7 Ba6-c8 Kd6-e5 Kc4-d3 Bg7-f8 Bc8-f5 Bf8-d6 Bf5-d7 Bd6-e7 Bd7-b5 Ke5-f4 Bb5-d7 Kf4-e5 Bd7-b5 Be7-c5 Bb5-d7 Bc5-a3 Bd7-b5 Ba3-c5 Bb5-d7 Bc5-d6 Bd7-b5 Bd6-e7 Bb5-d7 Be7-b4 Bd7-c8 Bb4-f8 Bc8-f5 Bf8-b4 Bf5-c8 Bb4-d6 Bc8-f5 Bd6-f8 Bf5-d7 Bf8-c5 Bd7-b5 Bc5-d6 Kd3-d2 Bd6-b4+ Kd2-e2 Bb4-d6 Bb5-d7 Bd6-a3 Bd7-c8 Ke5-f4 Ke2-d3 Kf4-e5 Kd3-e2 Ba3-e7 Bc8-f5 Be7-c5 Bf5-c8 Bc5-f8 Bc8-f5 Ke5-d5 Bf5-b1 Bf8-g7 Bb1-a2+ Kd5-c6 Ba2-b1 Bg7-f8 Bb1-a2 Bf8-c5 Ba2-b1 Bc5-a7 Bb1-a2 Kc6-b7 Ba2-b1 Ba7-b6 Bb1-a2 Kb7-a8 Ba2-b1 Ka8-a7 Bb1-a2 Bb6-c7 Ba2-b1 Bc7-d8 Bb1-a2 Ka7-a6 Ba2-b1 Bd8-e7 Bb1-a2 Be7-d8 Ba2-b1 Bd8-e7 Bb1-a2 Be7-b4 Ba2-b1 Ka6-b7 Bb1-a2 Kb7-c6 Ba2-b1 Bb4-a3 Bb1-a2 Ba3-c1 Ba2-b1 Bc1-f4 Bb1-a2 Kc6-c5 Ba2-b1 Kc5-b4 Bb1-a2 Kb4xa4 Ke2-d3 Ka4-a3 Ba2-c4 Bf4-e3 Kd3-c2 Ka3-b4 Kc2-d3 Kb4-a3 Kd3-c2 Be3-f2 Bc4-f7 Ka3-b4 Kc2-d3 Bf2-e3 Kd3-c2 Kb4-c5 Kc2-d3 Kc5-d6 Kd3-e4 Kd6-c5 Ke4-d3 Be3-g1 Bf7-g8 a5-a4 Bg8-f7 Bg1-e3 Bf7-e8 Kc5-b4 Be8-f7 Be3-f2 Kd3-c2 Bf2-e3 Bf7-e8 Be3-f4 Be8-f7 Bf4-d6 Bf7-g8 Bd6-e5 Bg8-f7 Be5-h2 Bf7-g6 Bh2-g3 Bg6-f7 Bg3-d6 Bf7-e6 Bd6-c7 Be6-f7 Bc7-b6 Bf7-g8 Bb6-a5 Bg8-f7 Ba5-b6 Bf7-g8 Bb6-a5 Bg8-f7 Ba5-c7 Bf7-g8 Bc7-b6 Bg8-f7 Kb4-a3 Bf7-g6 Ka3-b4 Bg6-f7 Bb6-c7 Bf7-g8 Kb4-c5 Kc2-d3 Bc7-g3 Bg8-f7 Bg3-f2 Kd3-c2 Kc5-b4 Bf7-g8 Bf2-e1 Bg8-f7 Be1-h4 Bf7-e6 Bh4-e1 Be6-f7 Be1-g3 Bf7-g8 Bg3-e5 Bg8-e6 Kb4-a3 Be6-f5 Ka3-b4 Bf5-e6 Be5-d6 Be6-f7 Kb4-a3 Bf7-g6 Ka3-b4 Bg6-f7 Bd6-e7 Bf7-g8 Be7-f8 Bg8-f7 Kb4-c5 Kc2-d3 Bf8-g7 Bf7-g8 Kc5-b4 Kd3-c2 Kb4-a3 Bg8-h7 Ka3-b4 Bh7-g8 Bg7-f6 Bg8-f7 Bf6-d8 Bf7-g8 Kb4-a3 Bg8-h7 Ka3-b4 Bh7-g8 Bd8-c7 Bg8-f7 Bc7-g3 Bf7-g8 a4-a3 Kc2-d3 Kb4-c5 Bg8-a2 Bg3-e1 Kd3-e4 Be1-c3 Ba2-g8 Kc5-d6 Bg8-a2 Kd6-e7 Ke4-d3 Bc3-a1 Kd3-e4 Ba1-b2 Ba2-c4 Bb2-c3 Bc4-g8 Ke7-d6 Bg8-a2 Kd6-e7 Ba2-g8 Bc3-b2 Bg8-b3 Ke7-d6 Bb3-c4 Kd6-c5 Bc4-a2 Kc5-b4 Ke4-d3 Bb2-a1 Ba2-g8 Kb4-b5 Bg8-a2 Ba1-b2 Ba2-f7 Kb5-b4 Bf7-g8 Kb4-c5 Bg8-f7 Kc5-b4 Bf7-c4 Kb4-c5 Bc4-g8 Bb2-c1 Bg8-f7 Bc1-e3 Bf7-a2 Be3-c1 Ba2-c4 Bc1-e3 Bc4-a2 Be3-c1 Kd3-e4 Bc1-b2 Ba2-g8 Kc5-d6 Bg8-c4 Kd6-c5 Ke4-d3 Kc5-b4 Bc4-g8 Kb4-c5 Bg8-f7 Kc5-d6 Kd3-e4 Kd6-c6 Bf7-c4 Kc6-d6 Bc4-f7 Kd6-c6 Bf7-a2 Kc6-c5 Ba2-f7 Bb2-c1 Ke4-d3 Bc1-b2 Kd3-e4 Kc5-b5 Ke4-d3 Kb5-c6 Bf7-c4 Bb2-c3 Kd3-e4 Kc6-c5 Bc4-f7 Bc3-d2 Bf7-a2 Bd2-c1 Ba2-g8 Bc1-e3 Bg8-a2 Kc5-b4 Ke4-d3 Kb4-c5 Kd3-e4 Be3-g1 Ba2-e6 Kc5-d6 Be6-f7 Kd6-c6 Bf7-a2 Kc6-c5 Ba2-d5 d4-d3 Bd5-g8 d3-d2 Ke4-f5 Kc5-b4 Kf5xg5 Kb4-c3 Bg8-f7 Kc3-c2 Kg5-f5 Kc2-b2 Bf7-d5 Bg1-a7 g4-g5 Ba7-e3 g5-g6 Be3-d4 Bd5-f7 Bd4-g7 Bf7-d5 a3-a2 Bd5-f3 Kb2-a3 Kf5-e6 Ka3-b4 Ke6-d7 Bg7-h8 Bf3-d1 a2-a1=Q g6-g7 Bh8xg7 Bd1-c2 Qa1-a7+ Kd7-e6 Qa7-a2+ B ...
# ---
# A game of chess with the moves 'Ng1-f3 d7-d5 c2-c4 d5-d4 b2-b4 g7-g6 g2-g3 Bf8-g7 d2-d3 e7-e5 Bf1-g2 Nb8-d7 a2-a4 Ng8-f6 Nb1-d2 O-O a4-a5 Rf8-e8 O-O Ra8-b8 Nf3-e1 c7-c5 Ne1-c2 h7-h5 Nd2-b3 b7-b5 a5xb6 Qd8xb6 e2-e3 c5xb4 e3xd4 Bg7-f8 Bc1-e3 e5xd4 Be3xd4 Nd7-c5 Ra1-a5 Bc8-g4 f2-f3 Nc5xb3 Bd4xb6 Rb8xb6 c4-c5 Rb6-e6 f3xg4 Nb3xa5 g4xh5 Nf6xh5 Bg2-d5 b4-b3 Bd5xe6 Re8xe6 Nc2-a1 b3-b2 d3-d4 Na5-c4 Na1-b3 Re6-f6 Rf1-e1 Bf8-h6 Qd1-d3 Nc4-a3 d4-d5 Bh6-g5 c5-c6 Bg5-f4 Qd3-d4 b2-b1=Q Re1xb1 Kg8-g7 g3xf4 Nh5xf4 Rb1-b2 Nf4-h3+ Kg1-h1 Na3-b5 Qd4-e5 Nh3-g5 Qe5xg5 Rf6-f1+ Kh1-g2 Rf1-f5 Qg5-d8 Nb5-c7 d5-d6 Nc7-e6 c6-c7 Ne6xd8 c7xd8=Q Rf5-d5 Qd8-e7 Kg7-h6 Rb2-f2 Rd5-g5+ Kg2-h1 Rg5-f5 Rf2xf5 g6xf5 d6-d7 f5-f4 d7-d8=Q f4-f3 Qe7-f6+ Kh6-h7 Qd8-h8#' ends with the result 1-0.
# ---
# After 'e2e4 c7c6 d2d4 d7d5 e4e5 c6c5 d4c5 b8c6 c1f4 e7e6 b1d2 f8c5 d2b3 c5b6 d1g4 e8f8 f1d3 a7a5 a2a4 c6b4 g1f3 h7h5 g4h3 c8d7 e1g1 g8e7 f4g5 a8c8 b3d4 b4d3 c2d3 b6c5 d4e2 d8b6 d3d4 b6b2 e2f4 c5b4 g5e7 f8e7 h3h4 e7e8 f4h5 e8f8 h4g4 h8g8 f3g5 b2c2 h5f4 f8e8 h2h4 c8c4 a1c1 c2f5 g4f5 e6f5 f4d5 c4d4 f1d1 d4d1 c1d1 g8h8 d5b4 a5b4 g5f7 h8h4 f7d6 e8e7 a4a5 b4b3 d6b7 d7c6 b7c5 h4b4 d1b1 c6d5 a5a6 b4b5 c5d3 g7g5 a6a7 b5a5 d3b4 e7e6 b4d5 e6d5 b1b3 a5a1 g1h2 a1a7 b3b5 d5e6 h2h3 a7a2 f2f3 a2a7 h3g3 a7a2 b5c5 a2a6 f3f4 a6a3 g3f2 g5f4 c5b5 a3a1 b5c5 a1a3 c5b5 a3a1 b5b6 e6e5 b6b5 e5f6 b5c5 a1a8 c5c3 f6g5 f2f3 a8a1 c3d3 a1f1 f3e2 f1a1 d3d8 a1a2 e2f3 a2a3 f3f2 a3a2 f2f1 f4f3 d8g8 g5f6 g2g3 a2c2 g8d8 f5f4 d8f8 f6g6 f8f4 c2c1 f1f2 c1a1 f4g4 g6f7 g4f4 f7g6 f4d4 a1a2 f2f3 g6g5 d4d5 g5g6 d5d6 g6h5 d6d8 a2a1 d8d5 h5h6 d5d6 h6h5 d6d5 h5g6 d5d6 g6h7 f3g4 a1a5 g4h4 a5b5 h4h3 b5b4 d6d7 h7h6 d7d6 h6h5 g3g4 h5g5 d6d5 g5h6 d5d6 h6g5 d6d5 g5h6 h3h4 b4b6 d5a5 h6g7 a5g5 g7h7 g5h5 h7g7 h5g5 g7h6 g5a5 h6g7 a5g5 g7h7 g5a5 h7g7 a5a7 g7h6 a7a8 b6e6 a8a1 e6b6 a1a5 h6g7 a5g5 g7h7 g5h5 h7g6 h5g5 g6h7 g5d5 b6e6 d5h5 h7g7 h5f5 e6h6 h4g5 h6g6 g5f4 g6b6 f4g5 b6g6 g5f4 g6a6 f4g5 a6g6 g5f4 g6a6 f4g5 a6g6 g5f4 g6d6 f5g5 g7h6 g5h5 h6g7 h5c5 d6f6 f4g5 f6g6 g5f4 g6f6 f4g5 f6g6 g5h5 g6h6 h5g5 h6g6 g5h4 g6h6 h4g5 h6g6 g5h4 g6h6 c5h5 h6a6 h5g5 g7h6 g5b5 h6g6 b5g5 g6h6 g5f5 a6d6 f5h5 h6g6 h5g5 g6h7 g5f5 h7g6 f5h5 d6d1 h5h6 g6h6 g4g5 h6g7 h4h3 d1d7 h3g3 d7a7 g3f2 a7a3 f2e2 g7g6 e2d2 a3a4 d2e2 g6f5 g5g6 a4a8 e2f3 a8a3 f3e2 a3a2 e2e3 a2a3 e3e2 a3a8 e2e3 a8e8 e3f3 e8c8 g6g7 c8g8 f3e3 g8e8 e3d3 e8g8 d3d4 f5e6 d4e4 e6f6 e4f4 g8g7 f4e3 f6e5 e3d3 e5d5 d3e3 g7a7 e3f4 a7g7 f4e3 g7e7 e3f4 e7e5 f4g4 e5e7 g4f4 e7e5 f4f3 e5e8 f3f4 e8e4 f4g5 d5e5 g5h6 e5f6 h6h7 e4e8 h7h6 e8h8' the result is 0-1.
# ---
# Given the chess position '. . . r . . k .
# p . . . p p b p
# . . p . . . p .
# q . . . P . . P
# . . . . . . . .
# . . B . . B . .
# P . . . Q P . P
# R r . . . K . .', a good next move is e7h7
# ---
# e2e4 c7c5 g1f3 d7d6 d2d4 c5d4 f3d4 g8f6 b1c3 g7g6 f2f4 b8c6 c1e3 f8g7 d1d2 e8g8 f1e2 c6d4 e3d4 e7e5 d4f2 g7h6 f2e3 d6d5 e4d5 e5f4 e3c5 c8g4 e1g1 f8e8 a1e1 b7b6 c5d4 g4e2 e1e2 f6g4 d2d3 e8e2 d3e2 g4e3 c3e4 h6g7 d4g7 g8g7 f1f4 e3d5 f4f1 d8e7 c2c4 a8e8 e2f3 f7f5 c4d5 e7e4 f3e4 f5e4 d5d6 e4e3 f1d1 e3e2 d1e1 e8e6 g1f2 e6d6 f2e2 d6d5 e1c1 g7f6 c1c7 d5a5 a2a3 a5b5 b2b4 a7a5 c7b7 f6g5 b4a5 b5a5 b7b6 a5a3 e2f2 a3a4 f2g3 a4a3 g3f2 a3a2 f2g3 g5h5 b6b3 a2a5 g3f2 a5a2 f2g3 a2a5 g3h3 g6g5 g2g4 h5g6 b3e3 h7h6 e3b3 a5a7 b3f3 a7a8 h3g3 a8a7 f3d3 g6f7 d3f3 f7g6 f3e3 a7a6 e3b3 a6a4 b3c3 a4a2 g3h3 a2a4 c3d3 a4a5 h3g3 a5a4 d3d6 g6g7 d6d7 g7f6 d7d6 f6e7 d6d3 e7f6 d3f3 f6g7 f3e3 a4a6 e3f3 a6a4 f3d3 a4a7 d3b3 a7a6 b3d3 a6a7 d3b3 a7a6 g3h3 a6a8 b3e3 h6h5 g4h5 g7h6 e3b3 h6h5 h3g3 g5g4 b3e3 a8a5 e3d3 a5a8 d3b3 a8a5 b3d3 a5a4 d3b3 h5g6 b3e3 a4a5 g3h4 g4g3 h4g3 a5a6 e3d3 a6a1 g3h4 a1a7 d3d6 g6f7 d6d3 a7a4 h4g5 f7g7 d3d7 g7h8 g5h5 a4a5 h5g4 a5a4 g4h5 a4a5 h5h4 a5a1 d7d8 h8h7 d8d7 h7h8 d7d8 h8h7 d8d7 h7g8 d7d8 g8g7 d8d7 g7h6 d7d6 h6g7 d6d7 g7g8 d7d8 g8f7
# ---
# In the position '2Q3Q1/5pk1/8/4p3/4P1Kp/5P2/p3R3/8 b - - 1 52' play g8g5.
# ---
# Continue 'Ng1-f3 d7-d5 g2-g3 Ng8-f6 Bf1-g2 g7-g6 O-O Bf8-g7 c2-c4 c7-c6 c4xd5 c6xd5 d2-d4 O-O Nb1-c3 Nb8-c6 Nf3-e5 Bc8-f5 Bc1-f4 Ra8-c8 Ra1-c1 h7-h6 Ne5xc6 Rc8xc6 Qd1-b3 Rc6-b6 Qb3-a3 g6-g5 Bf4-e5 e7-e6 b2-b3 Rb6-a6 Qa3-b4 Qd8-b6 Qb4xb6 Ra6xb6 Nc3-a4 Rb6-a6 Rc1-c7 b7-b5 Na4-c3 Rf8-a8 Rf1-a1 Nf6-e8 Rc7-b7 f7-f6 Rb7-b8 Ra8xb8 Be5xb8 Bf5-g6 a2-a4 b5xa4 Nc3xa4 Bg7-f8 Ra1-c1 Bf8-a3 Rc1-c8 Kg8-f7 Bg2-f1 Ra6-a5 Na4-c5 Kf7-e7 h2-h4 Ba3xc5 Rc8xc5 Ra5xc5 d4xc5 a7-a5 Bb8-a7 Bg6-c2 Ba7-b6 Bc2xb3 Bb6xa5 Ke7-d7 e2-e4 d5xe4 Bf1-b5+ Kd7-e7 Kg1-h2 Bb3-d5 Kh2-h3 e6-e5 h4xg5 f6xg5 Bb5xe8 Bd5-e6+ g3-g4 Ke7xe8 Kh3-g3 Ke8-f7 c5-c6 e4-e3 f2xe3 e5-e4 Ba5-b4 Be6-d5 c6-c7 Bd5-e6 Bb4-c5 Kf7-g8 Bc5-d6 Be6-c8 Bd6-c5 Kg8-g7 Bc5-b4 Bc8-a6 Bb4-e7 Kg7-h7 Be7-d6 Kh7-g6 Bd6-c5 Ba6-c8 Bc5-e7 Bc8-a6 Be7-c5 Ba6-b7 Bc5-e7 Kg6-h7 Be7-c5 Bb7-c8 Bc5-f8 Bc8-e6 Bf8-b4 Kh7-g6 Bb4-e7 Kg6-f7 Be7-b4 Kf7-g6 Bb4-f8 Be6-d7 Bf8-c5 Kg6-f7 Bc5-b4 Kf7-g7 Bb4-c5 Kg7-f7 Bc5-a3 Kf7-g8 Ba3-d6 Kg8-g7 Bd6-b4 Bd7-c8 Bb4-e7 Bc8-e6 Be7-d6 Be6-c8 Bd6-e5+ Kg7-h7 Be5-d6 Kh7-g7 Bd6-a3 Kg7-g8 Ba3-d6 Kg8-f7 Bd6-a3 Bc8-d7 Ba3-b4 Kf7-g7 Bb4-a3 Bd7-e6 Ba3-c5 Kg7-h7 Bc5-a3 Be6-c8 Ba3-c5 Bc8-b7 Bc5-a3 Kh7-g6 Ba3-b4 Kg6-f7 Bb4-a3 Kf7-g7 Ba3-c5 Bb7-a6 Bc5-e7 Ba6-c8 Be7-c5 Kg7-f7 Bc5-b4 Kf7-g8 Bb4-a3 Kg8-f7 Ba3-b4 Bc8-b7 Bb4-d6 Kf7-g8 Bd6-e7 Kg8-g7 Be7-c5 Bb7-c8 Bc5-d6 Bc8-e6 Bd6-e7 Kg7-f7 Be7-d6 Kf7-g6' with Bd6-f8
# ---
# In a game of chess, after 'c2-c4 f7-f5 d2-d4 Ng8-f6 Nb1-c3 e7-e6 e2-e3 b7-b6 Ng1-h3 Bf8-e7 Bf1-e2 Bc8-b7 O-O a7-a5 b2-b3 O-O Bc1-b2 Nf6-e4 Nc3-a4 Ne4-g5 Nh3-f4 Nb8-a6 f2-f3 Ng5-f7 Qd1-d2 Be7-g5' play Rook a1 to d1.
# ---
# e4 c5 Nf3 d6 d4 cxd4 Nxd4 Nf6 Nc3 Nc6 a3 e5 Nb3 Be7 Bg5 Be6 Qd3 a5 O-O-O a4 Nd2 O-O Nf3 Ra5 h4 h6 Bxf6 Bxf6 Nd5 Re8 Qe3 Bxd5 exd5 Nd4 Nxd4 exd4 Qh3 d3 c3 Qb6 Qxd3 Qxf2 Qh3 g6 h5 Re3 Qc8+ Kg7 Bd3 Rxd5 Rhf1 Qg3 Rxf6 Kxf6 Rf1+ Kg5 hxg6 Re1+ Rxe1 Qxe1+ Kc2 Qf2+ Kb1 fxg6 Bc2 Re5 Bxa4 Qf5+ Qxf5+ Kxf5 b4 h5 Bc2+ Kf6 a4 g5 a5 g4 c4 Ke7 Kb2 Kd8 Bd1 Re1 Bc2 Re5 b5 h4
# ---
# In the position '8/8/p1B4p/1p3p2/1P1Kn1kP/P7/8/8 b - - 11 54' play b1b4.
# ---
# d4 Nf6 c4 e6 e3 b6 Nc3 Bb7 a3 d5 Nf3 Bd6 cxd5 exd5 Nh4 g6 Be2 and then Ne4.
# ---
# In the position '. . . . . . . .
# p . . . . . . .
# . p . . k . . .
# . P . . . . . .
# . . . K P . n .
# P . . . . . . .
# . . . . . . B r
# . . . . . . R .' play c5b5.
# ---
# Given the chess position '8/8/8/2k2p2/5P2/3K4/8/8 w - - 42 168', after the move d3c3 the result is 1/2-1/2.
# ---
# d4 Nf6 Nf3 g6 Bg5 Bg7 c3 O-O Nbd2 d5 e3 c5 h3 Qb6 Qb3 c4 Qxb6 axb6 Be2 b5 Ne5 Nc6 a3 Re8 Bf4 Ne4 Nxc6 bxc6 Nxe4 dxe4 h4 h5 f3 e5 Bxe5 Bxe5 dxe5 Rxe5 O-O-O Bf5 f4 Rd5 Rxd5 cxd5 Rd1 Rd8 Kc2 f6 Ra1 Ra8 Rd1 Rd8 a4 Be6 axb5 Rb8 b4 Rxb5 Ra1 Rb7 Ra5 Kf8 Kb2 g5 Ra6 Ke7 fxg5 fxg5 hxg5 h4 Ra8 Kd6 Bh5 Ke5 Be8 Kf5 g6 Bd7 Bf7 Be6 Rf8 Kf6 Be8+ Kg7 Rf4 Rb8 Bc6 Kxg6 b5
# ---
# Starting from the position '. . . . . Q . .
# . . . . . . . .
# . . . . . . . .
# . . . . k . . .
# . . Q . . . . .
# . . . . . . . .
# . . . . . . . .
# K . . . . . . .' the move f8f4 is played. The game ends with the result 1-0.
# ---
# A game of chess with the moves 'd4 Nf6 Nc3 b6 e4 Bb7 e5 Nd5 Nxd5 Bxd5 h4 e6 Rh3 d6 h5 dxe5 dxe5 Nc6 Nf3 Be7 Bf4 O-O Bd3 Nb4 Rg3 f5 Be2 Be4 Kf1 Qe8 h6 g6 Ng5 Rd8 Qc1 Bxg5 Bxg5 Nxc2 Bxd8 Qxd8 Bc4 Nxa1 Bxe6+ Kh8 Qxa1 Qh4 Kg1 Qxh6 b4 Qg7 Re3 g5 f3 Bc6 Qc3 f4 Rd3 Be8 Rd5 h5 Qd4 g4 fxg4 hxg4 Bd7 g3 Bxe8 Rxe8 Qxf4 Qg6 Rd1 c5 e6 Qxe6 Qh4+ Kg7 Qxg3+ Kh7 Qh2+ Kg8 Qg3+ Kh7 bxc5 bxc5 Qh2+ Kg7 Qc7+ Re7 Qxc5 Qb6 Qd4+ Kg8 Qxb6 axb6 Rd8+ Kf7 Ra8 b5 Kh2 Re5 Ra6 b4 Ra7+ Kg6 Kh3 Rb5 Ra4 b3 axb3 Rxb3+ Kg4 Rb6 Kh4 Rd6 Rg4+ Kh6 Ra4 Kg6 Kg4 Rb6 Kh3 Kh6 Kg3 Kh5 Rh4+ Kg5 Rg4+ Kf6 Ra4 Kg5 Ra5+ Kg6 Kh4 Rb4+ g4 Rb6 Rg5+ Kh6 Ra5 Kg6 Rg5+ Kh6 Rf5 Kg7 Rg5+ Kh6 Rh5+ Kg7 Ra5 Kg6 Rg5+ Kh6 Rf5 Kg6 Rg5+ Kh6' ends with the result 1/2-1/2.
# ---
# Could you generate the bitboard code for the chess game using the provided PGN: 'd2d4 d7d5 c2c4 e7e6 c4d5 e6d5 b1c3 c7c6 c1f4 f8d6 f4d6 d8d6 d1b3 g8f6 e2e3 e8g8'? The bitboard generated is 'r n b . . r k .
# p p . . . p p p
# . . p q . n . .
# . . . p . . . .
# . . . P . . . .
# . Q N . P . . .
# P P . . . P P P
# R . . . K B N R'.
# ---
# Given the chess position 'Q4Q2/3k4/8/8/1N6/6K1/8/8 w - - 3 67', after the move a8c6 the result is 1-0.
# ---
# A game of chess with the moves 'd2-d4 d7-d5 c2-c4 e7-e6 Nb1-c3 a7-a6 c4xd5 e6xd5 Ng1-f3 Bf8-e7 Bc1-f4 Ng8-f6 e2-e3 Bc8-f5 Nf3-e5 c7-c6 g2-g4 Bf5-e6 g4-g5 Nf6-e4 Nc3xe4 d5xe4 Bf1-c4 Qd8-a5+ Ke1-f1 Be6xc4+ Ne5xc4 Qa5-f5 Rh1-g1 Nb8-d7 Qd1-g4 Qf5-d5 Ra1-c1 O-O h2-h4 a6-a5 h4-h5 a5-a4 Rg1-g3 b7-b5 Nc4-e5 Nd7xe5 Bf4xe5 c6-c5 Kf1-g2 Ra8-c8 b2-b4 a4xb3 a2xb3 Rc8-c6 Qg4-f4 Rc6-e6 Rg3-g4 c5xd4 e3xd4 f7-f6 g5xf6 e4-e3+ f2-f3 Be7xf6 Qf4-e4 Re6xe5 d4xe5 Qd5-d2+ Kg2-h3 Qd2xc1 Qe4-d5+ Kg8-h8 e5xf6 Qc1-h1+ Kh3-g3 Qh1-g1+ Kg3-h3 Qg1-h1+ Kh3-g3 Qh1-e1+ Kg3-h2 Qe1-f2+ Kh2-h3 g7xf6 Qd5-b7 Qf2-f1+ Kh3-h2 Qf1-f2+ Kh2-h3 Qf2-f1+ Kh3-h2 Qf1-f2+ Kh2-h3 Qf2-f1+ Kh3-h2 Qf1-f2+ Kh2-h3 Qf2-f1+ Kh3-h2 Qf1-f2+ Kh2-h3' ends with the result 1/2-1/2.
# ---
# A game of chess with the moves 'e2-e4 c7-c5 Ng1-f3 e7-e6 d2-d4 c5xd4 Nf3xd4 Nb8-c6 Nb1-c3 a7-a6 g2-g3 d7-d6 Bf1-g2 Bc8-d7 O-O Ng8-f6 a2-a4 Bf8-e7 Nd4xc6 Bd7xc6 a4-a5 h7-h6 Bc1-e3 O-O Be3-b6 Qd8-b8 Rf1-e1 Nf6-d7 Nc3-d5 Be7-d8 Bb6xd8 Rf8xd8 c2-c4 Kg8-h8 b2-b4 Qb8-a7 Qd1-c2 Qa7-b8 Re1-d1 Kh8-g8 Qc2-c3 Kg8-f8 Nd5-b6 Nd7xb6 a5xb6 Rd8-d7 c4-c5 Kf8-g8 e4-e5 Bc6xg2 Kg1xg2 d6-d5 Qc3-d4 Qb8-e8 Kg2-g1 Ra8-c8 Rd1-d3 Rd7-d8 Ra1-a3 Qe8-b5 h2-h4 Qb5-d7 Rd3-f3 Qd7-b5 Rf3-d3 Qb5-d7 Qd4-f4 Rc8-a8 h4-h5 Qd7-b5 Rd3-f3 Rd8-d7 Qf4-d4 Qb5-e2 Kg1-g2 Ra8-c8 Ra3-d3 Qe2-c2 g3-g4 a6-a5 b4xa5 Qc2xc5 Qd4xc5 Rc8xc5 Rd3-c3 Rc5-c4 Kg2-f1 Rd7-d8 Kf1-e2 Rc4-e4+ Ke2-d2 Rd8-a8 Rc3-c7 Re4-d4+ Kd2-c2 Ra8xa5 Rf3xf7 Rd4xg4 Rc7xb7 Ra5-b5 Rf7-c7 Kg8-h7 Rb7-b8 Rg4-g5 Rb8-b7 d5-d4 f2-f4 Rg5-g3 Rb7-b8 Rg3-h3 Rb8-b7 Rh3-g3 Rb7-b8 Rg3-h3 b6-b7 Rb5-b4 f4-f5 Rh3-h2+ Kc2-d3 Rh2-h3+ Kd3-d2 Rh3-h2+ Kd2-c1 Rh2-h1+ Kc1-c2 Rh1-h2+ Kc2-d3 Rh2-h3+ Kd3-d2 Rh3-h2+ Kd2-d3 Rh2-h3+ Kd3-d2 Rh3-h2+ Kd2-d3 Rh2-h3+ Kd3-d2 Rh3-h2+ Kd2-d3' ends with the result 1/2-1/2 due to fivefold repetition.
# ---
# d2d4 d7d5 c2c4 e7e6 b1c3 g8f6 g1f3 c7c5 c4d5 f6d5 e2e4 d5c3 b2c3 f8e7 f1d3 c5d4 c3d4 e8g8 e1g1 b7b6 d1e2 c8b7 f1d1 b8d7 a2a4 f8e8 c1d2 h7h6 h2h3 a7a6 f3h2 d7f6 h2f3 a6a5 e2e3 a8c8 d1b1 b7a8 b1b3 e7d6 a1b1 f6d7 f3h2 f7f5 e4e5 d6e7 d3b5 e7g5 f2f4 g5e7 b3c3 g8h7 c3c8 d8c8 b1c1 c8d8 h2f1 e8g8 b5c6 a8c6 c1c6 d7f8 g1h2 d8d7 c6b6 d7a4 e3d3 a4d7 d2e3 a5a4 f1g3 f8g6 d4d5 d7d5 d3d5 e6d5 g3f5 g8a8 b6b7 e7f8 g2g3 h7g8 e3d4 a8a6 h2g2 a4a3 g2f3 a3a2 d4a1 h6h5 h3h4 g8h7 f3e2 a6a4 b7d7 a4e4 e2d2 g6f4 g3f4 e4f4 d7f7 f8b4 d2c2 h7g6 e5e6 f4f5 f7g7 g6h6 e6e7 b4e7 g7e7 f5f1 a1b2 f1h1 e7d7 h1h4 d7d6 h6h7 d6d5 a2a1q b2a1 h4a4 d5d3 h5h4 c2d2 h4h3 d3h3 h7g6 a1f6 a4a7 f6e7 a7a8
# ---
# Starting from the FEN '6k1/2p2r1p/1p3p2/2bP3R/2P1rQP1/5P2/2R3K1/8 b - - 0 48', a good next move is b2b1
# ---
# Starting from the position '8/8/P7/8/8/2K3P1/5Q2/1k6 w - - 7 79' the move f2b2 is played. The game ends with the result 1-0.
# ---
# In chess after the moves 'Nf3 Nf6 c4 e6 Nc3 d5 d4 Be7 Bg5 h6 Bh4 O-O e3 Ne4 Bxe7 Qxe7 Rc1 c6 Bd3 Nxc3 Rxc3 Nd7 Bb1 dxc4 Qc2 f5 Rxc4 e5 Nxe5 Nxe5 dxe5 Qxe5 Rf4 Be6 g4 Rae8 O-O g6 Rd1 Rd8 Rfd4 Rxd4 Rxd4 c5 Rd2 Kg7 Qd3 b6 f4 Qf6 gxf5 Bxf5 e4 Be6 e5 Qf7', Bc2 is a good move.
# ---
# Starting from the bitboard position 'r n b q k b n r
# p p . p . p p p
# . . . . p . . .
# . . p . . . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R', a good move is f8h8
# ---
# In a game of chess, after 'd2-d4 Ng8-f6 c2-c4 e7-e6 g2-g3 d7-d5 Bf1-g2 Bf8-e7 Ng1-f3 O-O O-O a7-a5 Qd1-c2 c7-c6 Rf1-d1 Nb8-d7 a2-a3 b7-b6 Nb1-d2 Bc8-b7 e2-e4 Ra8-c8 e4-e5 Nf6-e8 b2-b4 a5xb4 a3xb4 Be7xb4 Ra1-a7 Rc8-b8 Nd2-f1 Bb4-e7 h2-h4 Ne8-c7 Nf3-g5 Be7xg5 Bc1xg5 Qd8-c8 Qc2-c1 d5xc4 h4-h5 Nc7-b5 h5-h6 f7-f6 Bg2-h3 Qc8-e8 h6xg7 Rf8-f7 e5xf6 Nd7xf6 Rd1-e1 Nb5xd4 Bh3-g2 Nd4-b5 Bg2-h3 Nb5-d4 Bh3-g2 Nd4-b5 Bg2-h3 Nb5-d4 Bh3-g2 Nd4-b5 Qc1xc4 Nf6-d5 Nf1-h2 Rf7xg7 Bg2xd5 c6xd5 Qc4-f4 Nb5xa7 Nh2-g4 Rg7-g6 Ng4-h6+ Rg6xh6 Bg5xh6 Na7-c6 Re1-e5 Nc6xe5 Qf4xe5 Qe8-e7 Qe5xb8+ Kg8-f7 Bh6-e3 e6-e5 Be3-g5 Qe7xg5 Qb8xb7+ Kf7-e6 Qb7-c6+ Ke6-f5 Qc6xd5 Qg5-c1+ Kg1-g2 Qc1-c7 f2-f3 h7-h5 Qd5-b3 Kf5-f6 Qb3-d3 Qc7-c5 Qd3-d8+ Kf6-f7 Qd8-d7+ Kf7-f6 Qd7-d8+ Kf6-e6 Qd8-g8+ Ke6-d6 Qg8-g6+ Kd6-d5 Qg6-e4+' play Kd5-e6.
# ---
# In chess after the moves 'd4', Nf6 is a good move.
# ---
# Starting from the FEN 'rnbqkbnr/1p1p1ppp/p3p3/8/3NP3/8/PPP2PPP/RNBQKB1R w KQkq - 0 5', a good next move is f2f6
# ---
# Given the chess position '. . . . . . . .
# . . b . . . . .
# . . . . . . . .
# . . . . . k . .
# . . . . . . . K
# . . . . . . . .
# . . q . . . . .
# . . . . . . . .', after the move c2h2 the result is 0-1 due to checkmate.
# ---
# After 'Nf3 d5 d4 Nf6 Bf4 c5 e3 cxd4 exd4 Nc6 Bd3 Bg4 c3 e6 O-O Nh5 Bd2 Nf6 h3 Bh5 Bf4 Ne4 Nbd2 Bd6 Bxd6 Nxd6 Re1 a6 Qb3 O-O Ne5 Rc8 Qc2 Nxd4 Qb1 N4f5 g4 Nh4 Bxh7+ Kh8 Bd3 f5 Re3 fxg4 hxg4 Qg5 Qe1 Rf4 Be2 Rcf8 Rh3 Kg8 Nd3 Bxg4 Rg3 Ne4 Nxe4 Rxe4 f4 Rfxf4 Nxf4 Nf3+ Bxf3 Rxe1+ Rxe1 Qxf4 Rxg4 Qxf3 Rg2 Qh3 Ree2 a5 a4 Qh6 Rg3 b6 Kg2 Kf7 Rh3 Qg5+ Rg3 Qh6 Kf3 g6 Rf2 Qh1+ Rfg2 e5 Rg5 Qe1 R2g4 Qd1+ Kg3 Qe2 Kh3 Qxb2 Rxg6 Qxc3+ Kh4 Qc2 Kh5 Qf5+ Kh6 d4 R6g5 Qf3 Rg7+ Ke6 R4g6+ Kd5 Rd7+ Kc4 Rgd6 Qf2 Kh5 Kd3 Kg5 e4 Kg4 Qf3+ Kg5 Qf2 Kg6 Qb2 Re6 e3 Rde7 Qh2 Kf6 e2 Re5 Qf2+ Kg5 Kd2 Kg6 d3 Kg7 e1=R Rxe1 Qxe1 Rf7 Qh4 Rf2+ Kc3 Rf8 Qg4+ Kh7 d2 Re8 d1=Q Re3+ Kd2 Rh3 Qdg1 Rd3+ Kxd3 Kh8 Qh1#' the game ends due to checkmate with the result 0-1.
# ---
# I would appreciate it if you could generate the Forsyth–Edwards Notation (FEN) that corresponds to the given PGN for the chess game: 'e2e4 c7c5 g1f3 e7e6 d2d4 c5d4 f3d4 b8c6 b1c3 g8f6 d4b5 d7d6 c1f4 e6e5 f4g5 a7a6 b5a3 b7b5 g5f6 d8f6 c3d5 f6d8 a3b1 a8b8 a2a4 b5b4 b1d2 g7g6 d2c4 f8h6 a4a5 e8g8 c4b6 c8e6 f1c4 c6a5 a1a5 e6d5 d1d5 b8b6 e1g1 d8a8 d5d3 a8c8 f1a1 c8c7 a5a6 b6a6 a1a6 h6c1 b2b3 f8d8 a6a4 d8b8 a4a6 b8b6 a6a8 b6b8 a8a6 b8b6 a6a2 g8g7 d3d1 c1a3 g2g3 h7h5 d1d5 b6c6 g1h1 c6c5 d5d3 c7b7 c2c3 c5c7 c4d5 b7c8 c3c4 c8h3 h1g1 h5h4 d3e3 h3g4'. The FEN code generated is '8/2r2pk1/3p2p1/3Bp3/1pP1P1qp/bP2Q1P1/R4P1P/6K1 w - - 2 42'.
# ---
# Starting from the bitboard position '. . . . . . . .
# . . . b r . . .
# . B . . . . B .
# P k . . . . . .
# . . p . . . . .
# . . P . . . . .
# . . . . . . . .
# . . K . . . . .', a good move is f7c4
# ---
# In chess, after the sequence 'e2e4 c7c5 c2c3 b7b6 d2d4 c8b7 f2f3 e7e6 c1e3 c5d4 e3d4 b8c6 d4f2 g8f6 f1b5 c6e5 b1d2 f8e7 g1h3 e8g8 d1e2 a7a6 b5a4 b6b5 a4c2 d8c7 e1g1 b5b4 f3f4 e5g6 f2d4 b4c3 b2c3 a6a5 c2d3 e7c5 a1b1 a8b8 e2e3 c5d4 c3d4 f6g4 e3g3 f7f5 e4f5 e6f5 d3f5 f8f5 g3g4 b8f8 g4e2 b7d5 b1c1 c7b6 e2e3 d5a2 d2e4 a2d5 e4g3 f5f7 c1c5 d5b7 f4f5 b7a6' a good move is f1d1.
# ---
# Given the chess position '. . . . . . . .
# . . . . . . . .
# . . . . . . Q .
# . . . . . . . .
# . . . . . . . k
# . . . . . K . .
# . . . . . . . .
# . . . . . . . .', after the move g6h6 the result is 1-0 due to checkmate.
# ---
# After 'c2c4 c7c6 e2e4 d7d5 e4d5 c6d5 c4d5 g8f6 b1c3 f6d5 d2d4 b8c6 g1f3 c8f5 f1c4 d5b6 c4b3 e7e6 e1g1 f8e7 c1e3 e8g8 d4d5 b6d5 c3d5 e6d5 d1d5 d8d5 b3d5 c6b4 a1d1 b4d5 d1d5 f5e6 d5a5 b7b6 a5a4 e7f6 e3d4 f6e7 d4e3 f8d8 h2h3 f7f6 f1a1 g8f7 a1c1 e6d7 a4d4 a8c8 c1c8 d7c8 d4d8 e7d8 f3d4 a7a6 f2f3 f7e8 d4c6 d8c7 c6d4 e8d7 g1f2 a6a5 d4e2 c8a6 g2g4 a6d3 e3d4 d7c6 f2e3 d3b1 a2a3 b1a2 h3h4 a2f7 h4h5 b6b5 f3f4 a5a4 h5h6 g7h6 d4f6 c7b6 f6d4 h6h5 d4b6 c6b6 g4h5 f7h5 e2g3 h5f7 f4f5 b5b4 g3e4 b4a3 b2a3 h7h6 e4d6 f7h5 e3f4 b6c6 f4e5 c6d7 d6c4 h5d1 e5f6 h6h5 f6g5 d7e7 f5f6 e7f7 c4d6 f7f8 d6b7 d1f3 b7d6 f3e2 g5h4 e2f3 h4g5 f3e2 d6b7 e2f3 b7d8 f8e8 d8e6 e8f7 e6d8 f7e8 d8e6 e8f7 e6c5 f3c6 c5a4 h5h4 g5h4 f7f6 a4b6 f6e5 b6d5 e5d4 h4g4 d4c4 g4f4 c6a4 d5c3 a4b5 c3a4 c4b3 a4c5 b3a3 f4e4 a3b4 e4d5 b5d3 c5b3 b4c3 d5c6 d3a6 c6d5 a6b7 d5c5 b7a6 b3d2 a6c4 d2e4 c3d3 e4f2 d3c3 f2e4 c3d3 c5b4 c4e6 e4c5 d3c2 c5b3 e6c4 b3d2 c4b3 b4c5 c2d3 c5b4 d3d4 d2c4 b3d1 c4e5 d1a4 e5f3 d4d3 f3e1 d3d4 e1c2 d4d3 c2e1 d3e4 b4c4 a4b3 c4c3 b3a2 e1f3 a2c4 f3d2 e4e3 d2e4 c4e6 e4f6 e6b3 f6g4 e3e4 g4f2 e4e3 f2e4 b3e6 e4f2 e6b3 f2h1 b3e6 h1g3 e6c4 g3f1 e3e4 f1g3 e4e3 g3f5 e3e4 f5e3 e4e5 e3d5 e5e4 d5e3 e4e5 e3g4 e5e4 g4f6 e4e3 f6g4 e3e4 g4e3 e4f3 c3d4 f3e2 e3f1 e2f3 f1e3 c4g8 e3f1 f3f4 d4c5 f4g4 c5b4 g8a2 f1d2 a2b1 b4a4 b1a2 d2b1 g4h3 b1c3 a2b1 a4b4 b1a2 b4a5 a2b1 a5b5 b1a2 b5c5 a2b1 c5d4 b1a2 d4e4 a2b1 e4e5 b1a2 c3d5 h3h4 d5f4 a2b1 f4e2 h4h3 e2c1 b1a2 e5d4 a2b1 c1a2 h3g2 a2c1 g2h2 c1a2 h2g3 a2c1 g3g2 c1a2 g2h3 a2c1 b1a2 d4d3 a2b1 d3e3 b1a2 e3f4 a2b1' the result is 1/2-1/2.
# ---
# In chess, after the sequence 'e2-e4 c7-c5 Ng1-f3 d7-d6 d2-d4 c5xd4 Nf3xd4 Ng8-f6 Nb1-c3 a7-a6 h2-h3 e7-e5 Nd4-b3 Bc8-e6 Bc1-e3 Nb8-d7 Qd1-d3 Ra8-c8 O-O-O b7-b5 g2-g4 h7-h6 Kc1-b1 Bf8-e7 f2-f4 e5xf4 Be3xf4 Nd7-e5 Qd3-e3 Qd8-c7 a2-a3 O-O Rh1-g1 g7-g5 Bf4-g3 b5-b4 a3xb4 Rc8-b8 Qe3-d4 Ne5-f3 Qd4-c5 d6xc5 Bg3xc7 Nf3xg1 Bc7xb8 Rf8xb8 Nb3xc5 Ng1-f3 Nc3-d5 Kg8-f8 Nd5xf6 Be7xf6 Bf1-e2 Nf3-e5 c2-c3 Bf6-d8 Nc5xa6 Rb8-a8 b4-b5 Ra8-c8 Kb1-c2 Ne5-c4 Rd1-a1 Nc4-d6 Ra1-d1 Nd6-c4 Rd1-a1 h6-h5 g4xh5 Be6xh3 Be2xc4 Rc8xc4 Kc2-d3 Rc4-c8' a good move is c3-c4.
# ---
